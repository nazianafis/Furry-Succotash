# %% [markdown]
# ## Install the dependencies.

# %%
# !pip install "tensorflow==2.6.0"
# !pip install transformers "datasets>=1.17.0" tensorboard --upgrade
# !pip install keras==2.6.*
# Out:
# Requirement already satisfied: tensorflow==2.6.0 in /usr/local/lib/python3.7/dist-packages (2.6.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.12.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (3.17.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.1.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (0.37.1)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (0.15.0)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (5.0)
# Requirement already satisfied: keras~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (2.6.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (0.4.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (3.7.4.3)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.44.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (3.3.0)
# Requirement already satisfied: tensorboard~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (2.9.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (3.1.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (1.19.5)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.6.0) (2.8.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.6.0) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.6->tensorflow==2.6.0) (3.3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.6.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.6.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow==2.6.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow==2.6.0) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow==2.6.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow==2.6.0) (3.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: datasets>=1.17.0 in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (2.9.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (1.19.5)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (6.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (0.70.12.2)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (2022.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (3.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (1.3.5)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (4.64.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (4.11.3)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (0.3.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (0.5.1)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets>=1.17.0) (0.18.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.17.0) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.17.0) (3.7.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets>=1.17.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets>=1.17.0) (3.0.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.17.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.17.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.17.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets>=1.17.0) (2021.10.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.53)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (0.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (0.6.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (3.17.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (1.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard) (57.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.4->tensorboard) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets>=1.17.0) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (21.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets>=1.17.0) (0.13.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.17.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets>=1.17.0) (2022.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: keras==2.6.* in /usr/local/lib/python3.7/dist-packages (2.6.0)

# %% [markdown]
# ## Login to HuggingFace.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub. Run the following command in your terminal in case you want to set this credential helper as the default
#
# git config --global credential.helper store

# %% [markdown]
# ## Select Model

# %%
model_id = "google/vit-base-patch16-224-in21k"

# %% [markdown]
# ## Download the Dataset.
# *This dataset has 21 classes and each class has 100 pics in it, making a grand total of 2100.

# %%
# !wget http://weegee.vision.ucmerced.edu/datasets/UCMerced_LandUse.zip
# !unzip UCMerced_LandUse.zip -d UCMerced
# Out:
# --2022-05-11 15:39:44--  http://weegee.vision.ucmerced.edu/datasets/UCMerced_LandUse.zip
# Resolving weegee.vision.ucmerced.edu (weegee.vision.ucmerced.edu)... 169.236.184.65
# Connecting to weegee.vision.ucmerced.edu (weegee.vision.ucmerced.edu)|169.236.184.65|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 332468434 (317M) [application/zip]
# Saving to: ‘UCMerced_LandUse.zip’
#
# UCMerced_LandUse.zi 100%[===================>] 317.07M  21.5MB/s    in 48s
#
# 2022-05-11 15:40:32 (6.58 MB/s) - ‘UCMerced_LandUse.zip’ saved [332468434/332468434]
#
# Archive:  UCMerced_LandUse.zip
#    creating: UCMerced/UCMerced_LandUse/Images/
#    creating: UCMerced/UCMerced_LandUse/Images/agricultural/
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/agricultural/agricultural99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/airplane/
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/airplane/airplane99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/beach/
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/beach/beach99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/buildings/
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/buildings/buildings99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/chaparral/
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/chaparral/chaparral99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/denseresidential/
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/denseresidential/denseresidential18.tif
# ...
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/storagetanks/storagetanks99.tif
#    creating: UCMerced/UCMerced_LandUse/Images/tenniscourt/
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt00.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt01.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt02.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt03.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt04.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt05.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt06.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt07.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt08.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt09.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt10.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt11.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt12.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt13.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt14.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt15.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt16.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt17.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt18.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt19.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt20.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt21.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt22.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt23.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt24.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt25.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt26.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt27.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt28.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt29.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt30.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt31.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt32.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt33.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt34.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt35.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt36.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt37.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt38.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt39.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt40.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt41.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt42.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt43.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt44.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt45.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt46.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt47.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt48.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt49.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt50.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt51.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt52.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt53.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt54.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt55.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt56.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt57.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt58.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt59.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt60.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt61.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt62.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt63.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt64.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt65.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt66.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt67.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt68.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt69.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt70.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt71.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt72.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt73.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt74.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt75.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt76.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt77.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt78.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt79.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt80.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt81.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt82.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt83.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt84.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt85.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt86.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt87.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt88.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt89.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt90.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt91.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt92.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt93.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt94.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt95.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt96.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt97.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt98.tif
#   inflating: UCMerced/UCMerced_LandUse/Images/tenniscourt/tenniscourt99.tif
#   inflating: UCMerced/UCMerced_LandUse/readme.txt
#   inflating: UCMerced/UCMerced_LandUse/readme.txt.bak

# %% [markdown]
# ## Checking the file structure of the zip.

# %%
# !ls UCMerced/UCMerced_LandUse/Images
# Out:
# agricultural	 denseresidential  mediumresidential  sparseresidential
# airplane	 forest		   mobilehomepark     storagetanks
# baseballdiamond  freeway	   overpass	      tenniscourt
# beach		 golfcourse	   parkinglot
# buildings	 harbor		   river
# chaparral	 intersection	   runway

# %% [markdown]
# ## Preprocessing

# %%
import os
import datasets

def create_image_folder_dataset(root_path):
  """creates `Dataset` from image folder structure"""
  
  # get class names by folders names
  _CLASS_NAMES= os.listdir(root_path)
  # defines `datasets` features`
  features=datasets.Features({
                      "img": datasets.Image(),
                      "label": datasets.features.ClassLabel(names=_CLASS_NAMES),
                  })
  # temp list holding datapoints for creation
  img_data_files=[]
  label_data_files=[]
  # load images into list for creation
  for img_class in os.listdir(root_path):
    for img in os.listdir(os.path.join(root_path,img_class)):
      path_=os.path.join(root_path,img_class,img)
      img_data_files.append(path_)
      label_data_files.append(img_class)
  # create dataset
  ds = datasets.Dataset.from_dict({"img":img_data_files,"label":label_data_files},features=features)
  return ds

# %%
ucmerced_ds = create_image_folder_dataset("UCMerced/UCMerced_LandUse/Images")

# %%
img_class_labels = ucmerced_ds.features["label"].names
ucmerced_ds
# Out:
# Dataset({
#     features: ['img', 'label'],
#     num_rows: 2100
# })

# %%
from transformers import ViTFeatureExtractor
from tensorflow import keras 
from tensorflow.keras import layers


feature_extractor = ViTFeatureExtractor.from_pretrained(model_id)

# learn more about data augmentation here: https://www.tensorflow.org/tutorials/images/data_augmentation
data_augmentation = keras.Sequential(
    [
        layers.Resizing(feature_extractor.size, feature_extractor.size),
        layers.Rescaling(1./255),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# use keras image data augementation processing
def augmentation(examples):
    # print(examples["img"])
    examples["pixel_values"] = [data_augmentation(image) for image in examples["img"]]
    return examples


# basic processing (only resizing)
def process(examples):
    examples.update(feature_extractor(examples['img'], ))
    return examples

# we are also renaming our label col to labels to use `.to_tf_dataset` later
ucmerced_ds = ucmerced_ds.rename_column("label", "labels")

# %% [markdown]
# Checking the names of the labels.

# %%
ucmerced_ds.features['labels'].names
# Out:
# ['agricultural',
#  'golfcourse',
#  'overpass',
#  'intersection',
#  'parkinglot',
#  'baseballdiamond',
#  'denseresidential',
#  'mobilehomepark',
#  'storagetanks',
#  'mediumresidential',
#  'runway',
#  'beach',
#  'harbor',
#  'sparseresidential',
#  'river',
#  'buildings',
#  'freeway',
#  'forest',
#  'airplane',
#  'tenniscourt',
#  'chaparral']

# %%
processed_dataset = ucmerced_ds.map(process, batched=True)
processed_dataset
# Out:
#   0%|          | 0/3 [00:00<?, ?ba/s]
# Dataset({
#     features: ['img', 'labels', 'pixel_values'],
#     num_rows: 2100
# })

# %%
# test size will be 15% of train dataset
test_size=.15

processed_dataset = processed_dataset.shuffle().train_test_split(test_size=test_size)
processed_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['img', 'labels', 'pixel_values'],
#         num_rows: 1785
#     })
#     test: Dataset({
#         features: ['img', 'labels', 'pixel_values'],
#         num_rows: 315
#     })
# })

# %%
from huggingface_hub import HfFolder
import tensorflow as tf

id2label = {str(i): label for i, label in enumerate(img_class_labels)}
label2id = {v: k for k, v in id2label.items()}

num_train_epochs = 5
train_batch_size = 32
eval_batch_size = 32
learning_rate = 3e-5
weight_decay_rate=0.01
num_warmup_steps=0
output_dir=model_id.split("/")[1]
hub_token = HfFolder.get_token() # or your token directly "hf_xxx"
hub_model_id = f'{model_id.split("/")[1]}-UCMerced' # change this to UCMerced
fp16=True

# Train in mixed-precision float16
# Comment this line out if you're using a GPU that will not benefit from this
if fp16:
  tf.keras.mixed_precision.set_global_policy("mixed_float16")

# %%
from transformers import DefaultDataCollator

# Data collator that will dynamically pad the inputs received, as well as the labels.
data_collator = DefaultDataCollator(return_tensors="tf")

# converting our train dataset to tf.data.Dataset
tf_train_dataset = processed_dataset["train"].to_tf_dataset(
   columns=['pixel_values'],
   label_cols=["labels"],
   shuffle=True,
   batch_size=train_batch_size,
   collate_fn=data_collator)

# converting our test dataset to tf.data.Dataset
tf_eval_dataset = processed_dataset["test"].to_tf_dataset(
   columns=['pixel_values'],
   label_cols=["labels"],
   shuffle=True,
   batch_size=eval_batch_size,
   collate_fn=data_collator)

# %%
import time
from transformers import TFViTForImageClassification, create_optimizer
import tensorflow as tf

# just wanted to see the runtime of this
start_time = time.time()

# create optimizer wight weigh decay
num_train_steps = len(tf_train_dataset) * num_train_epochs
optimizer, lr_schedule = create_optimizer(
    init_lr=learning_rate,
    num_train_steps=num_train_steps,
    weight_decay_rate=weight_decay_rate,
    num_warmup_steps=num_warmup_steps,
)

# load pre-trained ViT model
model = TFViTForImageClassification.from_pretrained(
    model_id,
    num_labels=len(img_class_labels),
    id2label=id2label,
    label2id=label2id,
)

# define loss
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# define metrics 
metrics=[
    tf.keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
    tf.keras.metrics.SparseTopKCategoricalAccuracy(3, name="top-3-accuracy"),
]

# compile model
model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics
              )

print("%s seconds" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-685683a24abd> in <module>()
#      20     num_labels=len(img_class_labels),
#      21     id2label=id2label,
# ---> 22     label2id=label2id,
#      23 )
#      24
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_tf_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    1801                 model(model.dummy_inputs)  # build the network with dummy inputs
#    1802         else:
# -> 1803             model(model.dummy_inputs)  # build the network with dummy inputs
#    1804
#    1805         assert os.path.isfile(resolved_archive_file), f"Error retrieving file {resolved_archive_file}"
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_tf_utils.py in run_call_with_unpacked_inputs(self, *args, **kwargs)
#     381         main_input = fn_args_and_kwargs.pop(main_input_name, None)
#     382         unpacked_inputs = input_processing(func, self.config, main_input, **fn_args_and_kwargs)
# --> 383         return func(self, **unpacked_inputs)
#     384
#     385     # Keras enforces the first layer argument to be passed, and checks it through `inspect.getfullargspec()`. This
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/vit/modeling_tf_vit.py in call(self, pixel_values, head_mask, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict, labels, training)
#     794             interpolate_pos_encoding=interpolate_pos_encoding,
#     795             return_dict=return_dict,
# --> 796             training=training,
#     797         )
#     798         sequence_output = outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_tf_utils.py in run_call_with_unpacked_inputs(self, *args, **kwargs)
#     381         main_input = fn_args_and_kwargs.pop(main_input_name, None)
#     382         unpacked_inputs = input_processing(func, self.config, main_input, **fn_args_and_kwargs)
# --> 383         return func(self, **unpacked_inputs)
#     384
#     385     # Keras enforces the first layer argument to be passed, and checks it through `inspect.getfullargspec()`. This
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/vit/modeling_tf_vit.py in call(self, pixel_values, head_mask, output_attentions, output_hidden_states, interpolate_pos_encoding, return_dict, training)
#     514             output_hidden_states=output_hidden_states,
#     515             return_dict=return_dict,
# --> 516             training=training,
#     517         )
#     518
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/vit/modeling_tf_vit.py in call(self, hidden_states, head_mask, output_attentions, output_hidden_states, return_dict, training)
#     434                 head_mask=head_mask[i],
#     435                 output_attentions=output_attentions,
# --> 436                 training=training,
#     437             )
#     438             hidden_states = layer_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/vit/modeling_tf_vit.py in call(self, hidden_states, head_mask, output_attentions, training)
#     387             head_mask=head_mask,
#     388             output_attentions=output_attentions,
# --> 389             training=training,
#     390         )
#     391         attention_output = attention_outputs[0]
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/vit/modeling_tf_vit.py in call(self, input_tensor, head_mask, output_attentions, training)
#     311     ) -> Tuple[tf.Tensor]:
#     312         self_outputs = self.self_attention(
# --> 313             hidden_states=input_tensor, head_mask=head_mask, output_attentions=output_attentions, training=training
#     314         )
#     315         attention_output = self.dense_output(
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/vit/modeling_tf_vit.py in call(self, hidden_states, head_mask, output_attentions, training)
#     239         batch_size = shape_list(hidden_states)[0]
#     240         mixed_query_layer = self.query(inputs=hidden_states)
# --> 241         mixed_key_layer = self.key(inputs=hidden_states)
#     242         mixed_value_layer = self.value(inputs=hidden_states)
#     243         query_layer = self.transpose_for_scores(mixed_query_layer, batch_size)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/layers/core.py in call(self, inputs)
#    1230     # Broadcast kernel to inputs.
#    1231     else:
# -> 1232       outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#    1233       # Reshape the output back to the original ndim of the input.
#    1234       if not tf.executing_eagerly():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in tensordot(a, b, axes, name)
#    5040     b_reshape, b_free_dims, b_free_dims_static = _tensordot_reshape(
#    5041         b, b_axes, True)
# -> 5042     ab_matmul = matmul(a_reshape, b_reshape)
#    5043     if isinstance(a_free_dims, list) and isinstance(b_free_dims, list):
#    5044       if (ab_matmul.get_shape().is_fully_defined() and
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3653       else:
#    3654         return gen_math_ops.mat_mul(
# -> 3655             a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    3656
#    3657
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    5691       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    5692         _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
# -> 5693         transpose_b)
#    5694       return _result
#    5695     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import os
from transformers.keras_callbacks import PushToHubCallback
from tensorflow.keras.callbacks import TensorBoard as TensorboardCallback, EarlyStopping

callbacks=[]

callbacks.append(TensorboardCallback(log_dir=os.path.join(output_dir,"logs")))
callbacks.append(EarlyStopping(monitor="val_accuracy",patience=1))
if hub_token:
  callbacks.append(PushToHubCallback(output_dir=output_dir,
                                     hub_model_id=hub_model_id,
                                     hub_token=hub_token))
# Out:
# Cloning https://huggingface.co/samu3l/vit-base-patch16-224-in21k-euroSat into local empty directory.

# %%
start_time = time.time()

train_results = model.fit(
    tf_train_dataset,
    validation_data=tf_eval_dataset,
    callbacks=callbacks,
    epochs=num_train_epochs,
)

print("%s seconds " % (time.time() - start_time))
# Out:
# Epoch 1/5

# %%
from huggingface_hub import HfApi

api = HfApi()

user = api.whoami(hub_token)


feature_extractor.save_pretrained(output_dir)

api.upload_file(
    token=hub_token,
    repo_id=f"{user['name']}/{hub_model_id}",
    path_or_fileobj=os.path.join(output_dir,"preprocessor_config.json"),
    path_in_repo="preprocessor_config.json",
)
